# %% [markdown]
# The user asks for a quick interpretation of their glucose control this week.
# I should not start from raw cgm_df because higher-level summary tables are already available and are the preferred first source.
# Only if those tables are insufficient should I inspect raw timestamps.

# %%
available = {
    "risk_df": len(risk_df),
    "daily_df": len(daily_df),
    "meal_features_df": len(meal_features_df),
    "meal_rule_df": len(meal_rule_df),
    "cgm_df": len(cgm_df),
}

print(f"""
Prefer higher-level tables first:
{available}

I already have enough structured evidence in risk_df / daily_df / meal_features_df / meal_rule_df.
Raw cgm_df inspection is unnecessary unless the user asks for exact timestamp-level event review.
""")
