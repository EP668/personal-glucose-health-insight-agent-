# %% [markdown]
# The user is asking for explanation of what HbA1c and OGTT mean and how they differ from CGM-based patterns.
# This requires background knowledge beyond the user's own tables.
# I should use search for explanation, but I should still connect the explanation back to the user's glucose-pattern question rather than replacing the analysis entirely.

# %%
search("What do HbA1c and OGTT measure in glucose regulation, and how are they different from CGM-based glycemic variability patterns?")
